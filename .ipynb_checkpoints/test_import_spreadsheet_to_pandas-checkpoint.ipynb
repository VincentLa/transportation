# %%
import pandas as pd
import requests
import io
import sqlalchemy as sa

KEY = '1VLAkWyYbMoqTnVlKMAU2p9DNNWm5nY5LaM8FJP9lAaQ'

# %%
URL = 'https://docs.google.com/spreadsheet/ccc'
params = {'key': KEY, 'output': 'csv'}
r = requests.get(URL, params = params)

conn = 'postgresql://VincentLa:pass@localhost:5432/VincentLa'

# %%
df = pd.read_csv(io.StringIO(r.text), sep = ',')

# %%
df.head()
# Out:
#         Date Departing Time Get On Transportation Get Off Transportation  \
# 0  9/22/2016     7:50:00 AM            8:02:00 AM             8:26:00 AM
# 1  9/22/2016     7:06:00 PM            7:23:00 PM             7:46:00 PM
# 2  9/23/2016     8:52:00 AM            8:57:00 AM             9:27:00 AM
# 3  9/26/2016     8:07:00 AM            8:10:00 AM             8:36:00 AM
# 4  9/26/2016     7:00:00 PM            7:07:00 PM             7:35:00 PM
#
#   Arrival Time Transportation Time Door to Door Time Transportation Type  \
# 0   8:30:00 AM             0:24:00           0:40:00             Chariot
# 1   7:50:00 PM             0:23:00           0:44:00             Chariot
# 2   9:30:00 AM             0:30:00           0:38:00                 38R
# 3   8:50:00 AM             0:26:00           0:43:00                38ax
# 4   7:39:00 PM             0:28:00           0:39:00                 38R
#
#               Route
# 0  Richmond to work
# 1  work to richmond
# 2  Richmond to work
# ...

# %%
engine = sa.create_engine(conn)

# %%
with engine.begin() as conn:
    df = pd.read_sql_table(table_name='claims_daily_status_new', con=conn, schema='data_ingest')
    df

# %%
df
# Out:
#                            source_info_uuid      claim_id subscriber_id  \
# 0      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162160033100     CP0000005
# 1      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162170021600     CP0000005
# 2      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162170021600     CP0000005
# 3      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162170021600     CP0000005
# 4      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162170021600     CP0000005
# 5      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162170021600     CP0000005
# 6      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162170021600     CP0000005
# 7      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162170021600     CP0000005
# 8      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162170021600     CP0000005
# 9      b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162190013500     CP0000009
# 10     b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162190013500     CP0000009
# 11     b803cc32-75b5-5ea7-9023-27c7e0ae51dc  162240008600     CP0000009
# ...
